# %% [markdown]
# # Assignment 3 Part 1: Developing Your Own Classifier

# %%
from google.colab import drive
drive.mount('/content/gdrive/',force_remount=True)

import sys
sys.path.append('/content/gdrive/My Drive/assignment3_p1_starterkit')
import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier_1 import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/gdrive/
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# !pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.5.1+cu101
#   Downloading https://download.pytorch.org/whl/cu101/torch-1.5.1%2Bcu101-cp36-cp36m-linux_x86_64.whl (704.4MB)
#      |████████████████████████████████| 704.4MB 24kB/s
# Collecting torchvision==0.6.1+cu101
#   Downloading https://download.pytorch.org/whl/cu101/torchvision-0.6.1%2Bcu101-cp36-cp36m-linux_x86_64.whl (6.6MB)
#      |████████████████████████████████| 6.6MB 41.8MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1+cu101) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1+cu101) (1.18.5)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.6.1+cu101) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.6.0+cu101
#     Uninstalling torch-1.6.0+cu101:
#       Successfully uninstalled torch-1.6.0+cu101
#   Found existing installation: torchvision 0.7.0+cu101
#     Uninstalling torchvision-0.7.0+cu101:
#       Successfully uninstalled torchvision-0.7.0+cu101
# Successfully installed torch-1.5.1+cu101 torchvision-0.6.1+cu101

# %%
import os
os.chdir('/content/gdrive/My Drive/assignment3_p1_starterkit')

# %%
import shutil 
shutil.copyfile("VOCtrainval_06-Nov-2007.tar.1", "/content/VOCtrainval_06-Nov-2007.tar.1")
# !tar -xf "/content/VOCtrainval_06-Nov-2007.tar.1" -C "/content/" 
shutil.move("/content/VOCdevkit/", "/content/VOCdevkit_2007")
# Out:
# '/content/VOCdevkit_2007'

# %% [markdown]
# # Part 1B: Design your own network
#
# In this notebook, your task is to create and train your own model for multi-label classification on VOC Pascal.
#
# ## What to do
# 1. You will make change on network architecture in ```classifier.py```.
# 2. You may also want to change other hyperparameters to assist your training to get a better performances. Hints will be given in the below instructions.
#
# ## What to submit
# Check the submission template for details what to submit.

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %% [markdown]
# # Developing Your Own Model

# %% [markdown]
# ### Goal
# To meet the benchmark for this assignment you will need to improve the network. Note you should have noticed pretrained Alenxt performs really well, but training Alexnet from scratch performs much worse. We hope you can design a better architecture over both the simple classifier and AlexNet to train from scratch.
#
# ### How to start
# You may take inspiration from other published architectures and architectures discussed in lecture. However, you are NOT allowed to use predefined models (e.g. models from torchvision) or use pretrained weights. Training must be done from scratch with your own custom model.
#
# #### Some hints
# There are a variety of different approaches you should try to improve performance from the simple classifier:
#
# * Network architecture changes
#     * Number of layers: try adding layers to make your network deeper
#     * Batch normalization: adding batch norm between layers will likely give you a significant performance increase
#     * Residual connections: as you increase the depth of your network, you will find that having residual connections like those in ResNet architectures will be helpful
# * Optimizer: Instead of plain SGD, you may want to add a learning rate schedule, add momentum, or use one of the other optimizers you have learned about like Adam. Check the `torch.optim` package for other optimizers
# * Data augmentation: You should use the `torchvision.transforms` module to try adding random resized crops and horizontal flips of the input data. Check `transforms.RandomResizedCrop` and `transforms.RandomHorizontalFlip` for this. Feel free to apply more [transforms](https://pytorch.org/docs/stable/torchvision/transforms.html) for data augmentation which can lead to better performance.
# * Epochs: Once you have found a generally good hyperparameter setting try training for more epochs
# * Loss function: You might want to add weighting to the `MultiLabelSoftMarginLoss` for classes that are less well represented or experiment with a different loss function
#
#
#
# #### Note
# We will soon be providing some initial expectations of mAP values as a function of epoch so you can get an early idea whether your implementation works without waiting a long time for training to converge.
#
# ### What to submit
# Submit your best model to Kaggle and save all plots for the writeup.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.RandomResizedCrop(227),
            transforms.CenterCrop(227),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize
        ])

test_transform = transforms.Compose([
            transforms.Resize(227),
            #transforms.RandomResizedCrop(227),
            transforms.CenterCrop(227),
            #transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])

# %%
ds_train = VocDataset('/content/VOCdevkit_2007/VOC2007/','train',train_transform)
ds_val = VocDataset('/content/VOCdevkit_2007/VOC2007/','val',test_transform)
ds_test = VocDataset('/content/gdrive/My Drive/assignment3_p1_starterkit/VOCdevkit_2007/VOC2007test/','test', test_transform)

# %%
num_epochs = 150
test_frequency = 5
batch_size = 32

train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1,drop_last=True)

val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=batch_size, 
                                               shuffle=True,
                                               num_workers=1,drop_last=True)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=batch_size, 
                                               shuffle=False,
                                               num_workers=1,drop_last=True)

# %%
# TODO: Run your own classifier here

classifier = Classifier().to(device)

criterion = nn.MultiLabelSoftMarginLoss()
#optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.98)
#optimizer = torch.optim.Adam(classifier.parameters(), lr=1e-4)
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.1, momentum=0.9) 
torch.optim.lr_scheduler.StepLR(optimizer, 4, gamma=0.001, last_epoch=-1)

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# Loss for Training on Epoch 1 is 0.3069544732570648
# -------  Class: aeroplane        AP:   0.1788  -------
# -------  Class: bicycle          AP:   0.0703  -------
# -------  Class: bird             AP:   0.0890  -------
# -------  Class: boat             AP:   0.0722  -------
# -------  Class: bottle           AP:   0.0587  -------
# -------  Class: bus              AP:   0.0621  -------
# -------  Class: car              AP:   0.2016  -------
# -------  Class: cat              AP:   0.0806  -------
# -------  Class: chair            AP:   0.1562  -------
# -------  Class: cow              AP:   0.0535  -------
# -------  Class: diningtable      AP:   0.0700  -------
# -------  Class: dog              AP:   0.0977  -------
# -------  Class: horse            AP:   0.0761  -------
# -------  Class: motorbike        AP:   0.0566  -------
# -------  Class: person           AP:   0.4825  -------
# -------  Class: pottedplant      AP:   0.0616  -------
# -------  Class: sheep            AP:   0.0348  -------
# -------  Class: sofa             AP:   0.1105  -------
# -------  Class: train            AP:   0.1232  -------
# -------  Class: tvmonitor        AP:   0.0680  -------
# mAP: 0.1102
# Avg loss: 0.22961540481983087
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.11019084409755517
# Starting epoch number 2
# Loss for Training on Epoch 2 is 0.23501770198345184
# Starting epoch number 3
# Loss for Training on Epoch 3 is 0.23012875020503998
# Starting epoch number 4
# Loss for Training on Epoch 4 is 0.22659443318843842
# Starting epoch number 5
# Loss for Training on Epoch 5 is 0.22453707456588745
# -------  Class: aeroplane        AP:   0.2790  -------
# -------  Class: bicycle          AP:   0.0836  -------
# -------  Class: bird             AP:   0.1691  -------
# -------  Class: boat             AP:   0.2082  -------
# -------  Class: bottle           AP:   0.0887  -------
# -------  Class: bus              AP:   0.1016  -------
# -------  Class: car              AP:   0.3723  -------
# -------  Class: cat              AP:   0.1887  -------
# -------  Class: chair            AP:   0.2594  -------
# -------  Class: cow              AP:   0.0689  -------
# -------  Class: diningtable      AP:   0.1355  -------
# -------  Class: dog              AP:   0.1400  -------
# -------  Class: horse            AP:   0.1242  -------
# -------  Class: motorbike        AP:   0.0763  -------
# -------  Class: person           AP:   0.5539  -------
# -------  Class: pottedplant      AP:   0.0808  -------
# -------  Class: sheep            AP:   0.0542  -------
# -------  Class: sofa             AP:   0.1863  -------
# -------  Class: train            AP:   0.1731  -------
# -------  Class: tvmonitor        AP:   0.1055  -------
# mAP: 0.1725
# Avg loss: 0.21440102599370173
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.17246923290573918
# Starting epoch number 6
# Loss for Training on Epoch 6 is 0.22297796607017517
# Starting epoch number 7
# Loss for Training on Epoch 7 is 0.22136615216732025
# Starting epoch number 8
# Loss for Training on Epoch 8 is 0.22114697098731995
# Starting epoch number 9
# Loss for Training on Epoch 9 is 0.22031168639659882
# Starting epoch number 10
# Loss for Training on Epoch 10 is 0.21736083924770355
# -------  Class: aeroplane        AP:   0.3302  -------
# -------  Class: bicycle          AP:   0.1213  -------
# -------  Class: bird             AP:   0.1850  -------
# -------  Class: boat             AP:   0.2122  -------
# -------  Class: bottle           AP:   0.1006  -------
# -------  Class: bus              AP:   0.0974  -------
# -------  Class: car              AP:   0.4458  -------
# -------  Class: cat              AP:   0.2159  -------
# -------  Class: chair            AP:   0.2666  -------
# -------  Class: cow              AP:   0.0995  -------
# -------  Class: diningtable      AP:   0.1266  -------
# -------  Class: dog              AP:   0.1690  -------
# -------  Class: horse            AP:   0.1194  -------
# -------  Class: motorbike        AP:   0.1160  -------
# -------  Class: person           AP:   0.6022  -------
# -------  Class: pottedplant      AP:   0.0713  -------
# -------  Class: sheep            AP:   0.0686  -------
# -------  Class: sofa             AP:   0.1876  -------
# -------  Class: train            AP:   0.2337  -------
# -------  Class: tvmonitor        AP:   0.1106  -------
# mAP: 0.1940
# Avg loss: 0.20905820165689176
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.19397934896729604
# Starting epoch number 11
# Loss for Training on Epoch 11 is 0.2169775366783142
# Starting epoch number 12
# Loss for Training on Epoch 12 is 0.21605364978313446
# Starting epoch number 13
# Loss for Training on Epoch 13 is 0.21516013145446777
# Starting epoch number 14
# Loss for Training on Epoch 14 is 0.2149324268102646
# Starting epoch number 15
# Loss for Training on Epoch 15 is 0.21357199549674988
# -------  Class: aeroplane        AP:   0.3992  -------
# -------  Class: bicycle          AP:   0.1743  -------
# -------  Class: bird             AP:   0.1329  -------
# -------  Class: boat             AP:   0.2451  -------
# -------  Class: bottle           AP:   0.1485  -------
# -------  Class: bus              AP:   0.1111  -------
# -------  Class: car              AP:   0.4545  -------
# -------  Class: cat              AP:   0.2226  -------
# -------  Class: chair            AP:   0.2969  -------
# -------  Class: cow              AP:   0.1222  -------
# -------  Class: diningtable      AP:   0.1963  -------
# -------  Class: dog              AP:   0.1593  -------
# -------  Class: horse            AP:   0.2331  -------
# -------  Class: motorbike        AP:   0.1683  -------
# -------  Class: person           AP:   0.6324  -------
# -------  Class: pottedplant      AP:   0.0915  -------
# -------  Class: sheep            AP:   0.0850  -------
# -------  Class: sofa             AP:   0.1865  -------
# -------  Class: train            AP:   0.2923  -------
# -------  Class: tvmonitor        AP:   0.1238  -------
# mAP: 0.2238
# Avg loss: 0.2048686662545571
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.22379408658101765
# Starting epoch number 16
# Loss for Training on Epoch 16 is 0.21135027706623077
# Starting epoch number 17
# Loss for Training on Epoch 17 is 0.21081005036830902
# Starting epoch number 18
# Loss for Training on Epoch 18 is 0.21134509146213531
# Starting epoch number 19
# Loss for Training on Epoch 19 is 0.2128066122531891
# Starting epoch number 20
# Loss for Training on Epoch 20 is 0.20962519943714142
# -------  Class: aeroplane        AP:   0.4461  -------
# -------  Class: bicycle          AP:   0.2336  -------
# -------  Class: bird             AP:   0.1918  -------
# -------  Class: boat             AP:   0.2645  -------
# -------  Class: bottle           AP:   0.1237  -------
# -------  Class: bus              AP:   0.1143  -------
# -------  Class: car              AP:   0.4812  -------
# -------  Class: cat              AP:   0.2586  -------
# -------  Class: chair            AP:   0.3265  -------
# -------  Class: cow              AP:   0.1110  -------
# -------  Class: diningtable      AP:   0.2228  -------
# -------  Class: dog              AP:   0.2001  -------
# -------  Class: horse            AP:   0.2691  -------
# -------  Class: motorbike        AP:   0.1994  -------
# -------  Class: person           AP:   0.6546  -------
# -------  Class: pottedplant      AP:   0.1032  -------
# -------  Class: sheep            AP:   0.1404  -------
# -------  Class: sofa             AP:   0.2038  -------
# -------  Class: train            AP:   0.2591  -------
# -------  Class: tvmonitor        AP:   0.1755  -------
# mAP: 0.2490
# Avg loss: 0.20121334798825094
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.24897649273302344
# Starting epoch number 21
# Loss for Training on Epoch 21 is 0.20893310010433197
# Starting epoch number 22
# Loss for Training on Epoch 22 is 0.20691074430942535
# Starting epoch number 23
# Loss for Training on Epoch 23 is 0.20549426972866058
# Starting epoch number 24
# Loss for Training on Epoch 24 is 0.20416606962680817
# Starting epoch number 25
# Loss for Training on Epoch 25 is 0.20569263398647308
# -------  Class: aeroplane        AP:   0.4078  -------
# -------  Class: bicycle          AP:   0.2002  -------
# -------  Class: bird             AP:   0.1904  -------
# -------  Class: boat             AP:   0.2169  -------
# -------  Class: bottle           AP:   0.1348  -------
# -------  Class: bus              AP:   0.0998  -------
# -------  Class: car              AP:   0.4796  -------
# -------  Class: cat              AP:   0.2284  -------
# -------  Class: chair            AP:   0.2822  -------
# -------  Class: cow              AP:   0.1245  -------
# -------  Class: diningtable      AP:   0.1864  -------
# -------  Class: dog              AP:   0.1941  -------
# -------  Class: horse            AP:   0.3255  -------
# -------  Class: motorbike        AP:   0.1941  -------
# -------  Class: person           AP:   0.6801  -------
# -------  Class: pottedplant      AP:   0.1101  -------
# -------  Class: sheep            AP:   0.1033  -------
# -------  Class: sofa             AP:   0.2565  -------
# -------  Class: train            AP:   0.2044  -------
# -------  Class: tvmonitor        AP:   0.1666  -------
# mAP: 0.2393
# Avg loss: 0.20228494818394
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 25 is 0.23929098150084177
# Starting epoch number 26
# Loss for Training on Epoch 26 is 0.20506155490875244
# Starting epoch number 27
# Loss for Training on Epoch 27 is 0.20389097929000854
# Starting epoch number 28
# Loss for Training on Epoch 28 is 0.20442943274974823
# Starting epoch number 29
# Loss for Training on Epoch 29 is 0.20222388207912445
# Starting epoch number 30
# Loss for Training on Epoch 30 is 0.20030632615089417
# -------  Class: aeroplane        AP:   0.4663  -------
# -------  Class: bicycle          AP:   0.2187  -------
# -------  Class: bird             AP:   0.1495  -------
# -------  Class: boat             AP:   0.3285  -------
# -------  Class: bottle           AP:   0.1520  -------
# -------  Class: bus              AP:   0.1375  -------
# -------  Class: car              AP:   0.5126  -------
# -------  Class: cat              AP:   0.2724  -------
# -------  Class: chair            AP:   0.3238  -------
# -------  Class: cow              AP:   0.1488  -------
# -------  Class: diningtable      AP:   0.2285  -------
# -------  Class: dog              AP:   0.2213  -------
# -------  Class: horse            AP:   0.4328  -------
# -------  Class: motorbike        AP:   0.2536  -------
# -------  Class: person           AP:   0.7007  -------
# -------  Class: pottedplant      AP:   0.1347  -------
# -------  Class: sheep            AP:   0.1292  -------
# -------  Class: sofa             AP:   0.2480  -------
# -------  Class: train            AP:   0.3171  -------
# -------  Class: tvmonitor        AP:   0.1886  -------
# mAP: 0.2782
# Avg loss: 0.19579049887565467
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 30 is 0.2782437202489715
# Starting epoch number 31
# Loss for Training on Epoch 31 is 0.1999218612909317
# Starting epoch number 32
# Loss for Training on Epoch 32 is 0.19773456454277039
# Starting epoch number 33
# Loss for Training on Epoch 33 is 0.19953417778015137
# Starting epoch number 34
# Loss for Training on Epoch 34 is 0.19868460297584534
# Starting epoch number 35
# Loss for Training on Epoch 35 is 0.19492660462856293
# -------  Class: aeroplane        AP:   0.4779  -------
# -------  Class: bicycle          AP:   0.2957  -------
# -------  Class: bird             AP:   0.1708  -------
# -------  Class: boat             AP:   0.3509  -------
# -------  Class: bottle           AP:   0.1408  -------
# -------  Class: bus              AP:   0.1596  -------
# -------  Class: car              AP:   0.5179  -------
# -------  Class: cat              AP:   0.2697  -------
# -------  Class: chair            AP:   0.3761  -------
# -------  Class: cow              AP:   0.1406  -------
# -------  Class: diningtable      AP:   0.2760  -------
# -------  Class: dog              AP:   0.2469  -------
# -------  Class: horse            AP:   0.4634  -------
# -------  Class: motorbike        AP:   0.2988  -------
# -------  Class: person           AP:   0.7176  -------
# -------  Class: pottedplant      AP:   0.1548  -------
# -------  Class: sheep            AP:   0.1215  -------
# -------  Class: sofa             AP:   0.2936  -------
# -------  Class: train            AP:   0.3314  -------
# -------  Class: tvmonitor        AP:   0.2073  -------
# mAP: 0.3006
# Avg loss: 0.19152469550951934
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 35 is 0.30056764736251274
# Starting epoch number 36
# Loss for Training on Epoch 36 is 0.19828194379806519
# Starting epoch number 37
# Loss for Training on Epoch 37 is 0.19819386303424835
# Starting epoch number 38
# Loss for Training on Epoch 38 is 0.1932816505432129
# Starting epoch number 39
# Loss for Training on Epoch 39 is 0.19265972077846527
# Starting epoch number 40
# Loss for Training on Epoch 40 is 0.19517655670642853
# -------  Class: aeroplane        AP:   0.4687  -------
# -------  Class: bicycle          AP:   0.2694  -------
# -------  Class: bird             AP:   0.2084  -------
# -------  Class: boat             AP:   0.3677  -------
# -------  Class: bottle           AP:   0.1617  -------
# -------  Class: bus              AP:   0.1904  -------
# -------  Class: car              AP:   0.5344  -------
# -------  Class: cat              AP:   0.2815  -------
# -------  Class: chair            AP:   0.4013  -------
# -------  Class: cow              AP:   0.1959  -------
# -------  Class: diningtable      AP:   0.2800  -------
# -------  Class: dog              AP:   0.2453  -------
# -------  Class: horse            AP:   0.4756  -------
# -------  Class: motorbike        AP:   0.3614  -------
# -------  Class: person           AP:   0.7365  -------
# -------  Class: pottedplant      AP:   0.1490  -------
# -------  Class: sheep            AP:   0.1514  -------
# -------  Class: sofa             AP:   0.2798  -------
# -------  Class: train            AP:   0.3653  -------
# -------  Class: tvmonitor        AP:   0.2502  -------
# mAP: 0.3187
# Avg loss: 0.18839749235373277
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 40 is 0.31870285087494604
# Starting epoch number 41
# Loss for Training on Epoch 41 is 0.1914689540863037
# Starting epoch number 42
# Loss for Training on Epoch 42 is 0.19353319704532623
# Starting epoch number 43
# Loss for Training on Epoch 43 is 0.19414553046226501
# Starting epoch number 44
# Loss for Training on Epoch 44 is 0.18797436356544495
# Starting epoch number 45
# Loss for Training on Epoch 45 is 0.189054474234581
# -------  Class: aeroplane        AP:   0.5241  -------
# -------  Class: bicycle          AP:   0.3026  -------
# -------  Class: bird             AP:   0.2053  -------
# -------  Class: boat             AP:   0.2712  -------
# -------  Class: bottle           AP:   0.1528  -------
# -------  Class: bus              AP:   0.1811  -------
# -------  Class: car              AP:   0.5396  -------
# -------  Class: cat              AP:   0.2740  -------
# -------  Class: chair            AP:   0.4099  -------
# -------  Class: cow              AP:   0.1539  -------
# -------  Class: diningtable      AP:   0.2850  -------
# -------  Class: dog              AP:   0.2498  -------
# -------  Class: horse            AP:   0.5095  -------
# -------  Class: motorbike        AP:   0.3994  -------
# -------  Class: person           AP:   0.7127  -------
# -------  Class: pottedplant      AP:   0.1232  -------
# -------  Class: sheep            AP:   0.1304  -------
# -------  Class: sofa             AP:   0.2813  -------
# -------  Class: train            AP:   0.3517  -------
# -------  Class: tvmonitor        AP:   0.2615  -------
# mAP: 0.3159
# Avg loss: 0.19306642714983377
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 45 is 0.31593897594378595
# Starting epoch number 46
# Loss for Training on Epoch 46 is 0.18932773172855377
# Starting epoch number 47
# Loss for Training on Epoch 47 is 0.18917974829673767
# Starting epoch number 48
# Loss for Training on Epoch 48 is 0.1893247663974762
# Starting epoch number 49
# Loss for Training on Epoch 49 is 0.18839220702648163
# Starting epoch number 50
# Loss for Training on Epoch 50 is 0.18946747481822968
# -------  Class: aeroplane        AP:   0.5446  -------
# -------  Class: bicycle          AP:   0.3283  -------
# -------  Class: bird             AP:   0.2383  -------
# -------  Class: boat             AP:   0.3837  -------
# -------  Class: bottle           AP:   0.1414  -------
# -------  Class: bus              AP:   0.1965  -------
# -------  Class: car              AP:   0.5346  -------
# -------  Class: cat              AP:   0.2654  -------
# -------  Class: chair            AP:   0.4156  -------
# -------  Class: cow              AP:   0.1552  -------
# -------  Class: diningtable      AP:   0.2502  -------
# -------  Class: dog              AP:   0.2648  -------
# -------  Class: horse            AP:   0.4948  -------
# -------  Class: motorbike        AP:   0.3770  -------
# -------  Class: person           AP:   0.7348  -------
# -------  Class: pottedplant      AP:   0.1303  -------
# -------  Class: sheep            AP:   0.1387  -------
# -------  Class: sofa             AP:   0.2500  -------
# -------  Class: train            AP:   0.3681  -------
# -------  Class: tvmonitor        AP:   0.2518  -------
# mAP: 0.3232
# Avg loss: 0.1868684777082541
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 50 is 0.32320738342420563
# Starting epoch number 51
# Loss for Training on Epoch 51 is 0.18918131291866302
# Starting epoch number 52
# Loss for Training on Epoch 52 is 0.185149148106575
# Starting epoch number 53
# Loss for Training on Epoch 53 is 0.1842893809080124
# Starting epoch number 54
# Loss for Training on Epoch 54 is 0.18537938594818115
# Starting epoch number 55
# Loss for Training on Epoch 55 is 0.18228046596050262
# -------  Class: aeroplane        AP:   0.5254  -------
# -------  Class: bicycle          AP:   0.3514  -------
# -------  Class: bird             AP:   0.2566  -------
# -------  Class: boat             AP:   0.3473  -------
# -------  Class: bottle           AP:   0.1538  -------
# -------  Class: bus              AP:   0.1932  -------
# -------  Class: car              AP:   0.5653  -------
# -------  Class: cat              AP:   0.3104  -------
# -------  Class: chair            AP:   0.4343  -------
# -------  Class: cow              AP:   0.1908  -------
# -------  Class: diningtable      AP:   0.3304  -------
# -------  Class: dog              AP:   0.2450  -------
# -------  Class: horse            AP:   0.4931  -------
# -------  Class: motorbike        AP:   0.3981  -------
# -------  Class: person           AP:   0.7515  -------
# -------  Class: pottedplant      AP:   0.1490  -------
# -------  Class: sheep            AP:   0.1767  -------
# -------  Class: sofa             AP:   0.2854  -------
# -------  Class: train            AP:   0.4005  -------
# -------  Class: tvmonitor        AP:   0.2655  -------
# mAP: 0.3412
# Avg loss: 0.18500506591338378
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 55 is 0.341186364069583
# Starting epoch number 56
# Loss for Training on Epoch 56 is 0.1837519109249115
# Starting epoch number 57
# Loss for Training on Epoch 57 is 0.18375907838344574
# Starting epoch number 58
# Loss for Training on Epoch 58 is 0.18165311217308044
# Starting epoch number 59
# Loss for Training on Epoch 59 is 0.1833772212266922
# Starting epoch number 60
# Loss for Training on Epoch 60 is 0.1829918622970581
# -------  Class: aeroplane        AP:   0.4743  -------
# -------  Class: bicycle          AP:   0.3737  -------
# -------  Class: bird             AP:   0.2472  -------
# -------  Class: boat             AP:   0.3303  -------
# -------  Class: bottle           AP:   0.1615  -------
# -------  Class: bus              AP:   0.2205  -------
# -------  Class: car              AP:   0.5511  -------
# -------  Class: cat              AP:   0.2717  -------
# -------  Class: chair            AP:   0.4667  -------
# -------  Class: cow              AP:   0.1376  -------
# -------  Class: diningtable      AP:   0.2915  -------
# -------  Class: dog              AP:   0.2588  -------
# -------  Class: horse            AP:   0.5310  -------
# -------  Class: motorbike        AP:   0.4819  -------
# -------  Class: person           AP:   0.7624  -------
# -------  Class: pottedplant      AP:   0.1322  -------
# -------  Class: sheep            AP:   0.1719  -------
# -------  Class: sofa             AP:   0.3109  -------
# -------  Class: train            AP:   0.4309  -------
# -------  Class: tvmonitor        AP:   0.3286  -------
# mAP: 0.3467
# Avg loss: 0.18155009662493682
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 60 is 0.3467350558984303
# Starting epoch number 61
# Loss for Training on Epoch 61 is 0.1779673993587494
# Starting epoch number 62
# Loss for Training on Epoch 62 is 0.1811233013868332
# Starting epoch number 63
# Loss for Training on Epoch 63 is 0.17939533293247223
# Starting epoch number 64
# Loss for Training on Epoch 64 is 0.18221350014209747
# Starting epoch number 65
# Loss for Training on Epoch 65 is 0.1798047572374344
# -------  Class: aeroplane        AP:   0.5557  -------
# -------  Class: bicycle          AP:   0.3792  -------
# -------  Class: bird             AP:   0.2232  -------
# -------  Class: boat             AP:   0.3387  -------
# -------  Class: bottle           AP:   0.1484  -------
# -------  Class: bus              AP:   0.1760  -------
# -------  Class: car              AP:   0.5857  -------
# -------  Class: cat              AP:   0.3120  -------
# -------  Class: chair            AP:   0.4565  -------
# -------  Class: cow              AP:   0.1980  -------
# -------  Class: diningtable      AP:   0.2922  -------
# -------  Class: dog              AP:   0.2730  -------
# -------  Class: horse            AP:   0.5370  -------
# -------  Class: motorbike        AP:   0.4468  -------
# -------  Class: person           AP:   0.7500  -------
# -------  Class: pottedplant      AP:   0.1499  -------
# -------  Class: sheep            AP:   0.1602  -------
# -------  Class: sofa             AP:   0.3035  -------
# -------  Class: train            AP:   0.4997  -------
# -------  Class: tvmonitor        AP:   0.3179  -------
# mAP: 0.3552
# Avg loss: 0.179058882383964
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 65 is 0.3551751828493538
# Starting epoch number 66
# Loss for Training on Epoch 66 is 0.17986898124217987
# Starting epoch number 67
# Loss for Training on Epoch 67 is 0.1775057464838028
# Starting epoch number 68
# Loss for Training on Epoch 68 is 0.17628449201583862
# Starting epoch number 69
# Loss for Training on Epoch 69 is 0.17741534113883972
# Starting epoch number 70
# Loss for Training on Epoch 70 is 0.1794184446334839
# -------  Class: aeroplane        AP:   0.5201  -------
# -------  Class: bicycle          AP:   0.3169  -------
# -------  Class: bird             AP:   0.2219  -------
# -------  Class: boat             AP:   0.3010  -------
# -------  Class: bottle           AP:   0.1445  -------
# -------  Class: bus              AP:   0.2338  -------
# -------  Class: car              AP:   0.5568  -------
# -------  Class: cat              AP:   0.3233  -------
# -------  Class: chair            AP:   0.4617  -------
# -------  Class: cow              AP:   0.1631  -------
# -------  Class: diningtable      AP:   0.2832  -------
# -------  Class: dog              AP:   0.2589  -------
# -------  Class: horse            AP:   0.5242  -------
# -------  Class: motorbike        AP:   0.4275  -------
# -------  Class: person           AP:   0.7471  -------
# -------  Class: pottedplant      AP:   0.1967  -------
# -------  Class: sheep            AP:   0.1821  -------
# -------  Class: sofa             AP:   0.3071  -------
# -------  Class: train            AP:   0.4556  -------
# -------  Class: tvmonitor        AP:   0.3190  -------
# mAP: 0.3472
# Avg loss: 0.18339381825465423
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 70 is 0.34722755114081927
# Starting epoch number 71
# Loss for Training on Epoch 71 is 0.17807549238204956
# Starting epoch number 72
# Loss for Training on Epoch 72 is 0.17548827826976776
# Starting epoch number 73
# Loss for Training on Epoch 73 is 0.17682629823684692
# Starting epoch number 74
# Loss for Training on Epoch 74 is 0.1738552451133728
# Starting epoch number 75
# Loss for Training on Epoch 75 is 0.17498144507408142
# -------  Class: aeroplane        AP:   0.5262  -------
# -------  Class: bicycle          AP:   0.3069  -------
# -------  Class: bird             AP:   0.2312  -------
# -------  Class: boat             AP:   0.3935  -------
# -------  Class: bottle           AP:   0.1719  -------
# -------  Class: bus              AP:   0.2038  -------
# -------  Class: car              AP:   0.5668  -------
# -------  Class: cat              AP:   0.3264  -------
# -------  Class: chair            AP:   0.4775  -------
# -------  Class: cow              AP:   0.1752  -------
# -------  Class: diningtable      AP:   0.3268  -------
# -------  Class: dog              AP:   0.2735  -------
# -------  Class: horse            AP:   0.5477  -------
# -------  Class: motorbike        AP:   0.3931  -------
# -------  Class: person           AP:   0.7611  -------
# -------  Class: pottedplant      AP:   0.1568  -------
# -------  Class: sheep            AP:   0.1731  -------
# -------  Class: sofa             AP:   0.3183  -------
# -------  Class: train            AP:   0.3950  -------
# -------  Class: tvmonitor        AP:   0.3286  -------
# mAP: 0.3527
# Avg loss: 0.18572569562074465
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 75 is 0.35267091626701164
# Starting epoch number 76
# Loss for Training on Epoch 76 is 0.1741662174463272
# Starting epoch number 77
# Loss for Training on Epoch 77 is 0.17312407493591309
# Starting epoch number 78
# Loss for Training on Epoch 78 is 0.1746998131275177
# Starting epoch number 79
# Loss for Training on Epoch 79 is 0.17449474334716797
# Starting epoch number 80
# Loss for Training on Epoch 80 is 0.17228826880455017
# -------  Class: aeroplane        AP:   0.5708  -------
# -------  Class: bicycle          AP:   0.3609  -------
# -------  Class: bird             AP:   0.2293  -------
# -------  Class: boat             AP:   0.3914  -------
# -------  Class: bottle           AP:   0.1535  -------
# -------  Class: bus              AP:   0.2623  -------
# -------  Class: car              AP:   0.5902  -------
# -------  Class: cat              AP:   0.3391  -------
# -------  Class: chair            AP:   0.4409  -------
# -------  Class: cow              AP:   0.1814  -------
# -------  Class: diningtable      AP:   0.3122  -------
# -------  Class: dog              AP:   0.2657  -------
# -------  Class: horse            AP:   0.5376  -------
# -------  Class: motorbike        AP:   0.5382  -------
# -------  Class: person           AP:   0.7692  -------
# -------  Class: pottedplant      AP:   0.1511  -------
# -------  Class: sheep            AP:   0.1366  -------
# -------  Class: sofa             AP:   0.2645  -------
# -------  Class: train            AP:   0.3725  -------
# -------  Class: tvmonitor        AP:   0.2954  -------
# mAP: 0.3581
# Avg loss: 0.1880070141110665
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 80 is 0.3581315727279252
# Starting epoch number 81
# Loss for Training on Epoch 81 is 0.17172236740589142
# Starting epoch number 82
# Loss for Training on Epoch 82 is 0.16955843567848206
# Starting epoch number 83
# Loss for Training on Epoch 83 is 0.17233358323574066
# Starting epoch number 84
# Loss for Training on Epoch 84 is 0.17162346839904785
# Starting epoch number 85
# Loss for Training on Epoch 85 is 0.1705123484134674
# -------  Class: aeroplane        AP:   0.5523  -------
# -------  Class: bicycle          AP:   0.3340  -------
# -------  Class: bird             AP:   0.2959  -------
# -------  Class: boat             AP:   0.4075  -------
# -------  Class: bottle           AP:   0.1859  -------
# -------  Class: bus              AP:   0.2052  -------
# -------  Class: car              AP:   0.5777  -------
# -------  Class: cat              AP:   0.3455  -------
# -------  Class: chair            AP:   0.4475  -------
# -------  Class: cow              AP:   0.1744  -------
# -------  Class: diningtable      AP:   0.2904  -------
# -------  Class: dog              AP:   0.2783  -------
# -------  Class: horse            AP:   0.5783  -------
# -------  Class: motorbike        AP:   0.5209  -------
# -------  Class: person           AP:   0.7716  -------
# -------  Class: pottedplant      AP:   0.1584  -------
# -------  Class: sheep            AP:   0.1599  -------
# -------  Class: sofa             AP:   0.3331  -------
# -------  Class: train            AP:   0.5260  -------
# -------  Class: tvmonitor        AP:   0.3364  -------
# mAP: 0.3740
# Avg loss: 0.1818325978059035
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 85 is 0.37396523264369996
# Starting epoch number 86
# Loss for Training on Epoch 86 is 0.16858337819576263
# Starting epoch number 87
# Loss for Training on Epoch 87 is 0.16918785870075226
# Starting epoch number 88
# Loss for Training on Epoch 88 is 0.17310719192028046
# Starting epoch number 89
# Loss for Training on Epoch 89 is 0.1690443456172943
# Starting epoch number 90
# Loss for Training on Epoch 90 is 0.1693783551454544
# -------  Class: aeroplane        AP:   0.6012  -------
# -------  Class: bicycle          AP:   0.3442  -------
# -------  Class: bird             AP:   0.2930  -------
# -------  Class: boat             AP:   0.3752  -------
# -------  Class: bottle           AP:   0.1436  -------
# -------  Class: bus              AP:   0.2217  -------
# -------  Class: car              AP:   0.5942  -------
# -------  Class: cat              AP:   0.3385  -------
# -------  Class: chair            AP:   0.4654  -------
# -------  Class: cow              AP:   0.1567  -------
# -------  Class: diningtable      AP:   0.2933  -------
# -------  Class: dog              AP:   0.2872  -------
# -------  Class: horse            AP:   0.5472  -------
# -------  Class: motorbike        AP:   0.5094  -------
# -------  Class: person           AP:   0.7735  -------
# -------  Class: pottedplant      AP:   0.1538  -------
# -------  Class: sheep            AP:   0.1655  -------
# -------  Class: sofa             AP:   0.3275  -------
# -------  Class: train            AP:   0.4468  -------
# -------  Class: tvmonitor        AP:   0.3739  -------
# mAP: 0.3706
# Avg loss: 0.17999576433346823
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 90 is 0.37058513685768457
# Starting epoch number 91
# Loss for Training on Epoch 91 is 0.16588617861270905
# Starting epoch number 92
# Loss for Training on Epoch 92 is 0.1648009568452835
# Starting epoch number 93
# Loss for Training on Epoch 93 is 0.16601334512233734
# Starting epoch number 94
# Loss for Training on Epoch 94 is 0.1668681651353836
# Starting epoch number 95
# Loss for Training on Epoch 95 is 0.1672365516424179
# -------  Class: aeroplane        AP:   0.6266  -------
# -------  Class: bicycle          AP:   0.3954  -------
# -------  Class: bird             AP:   0.2563  -------
# -------  Class: boat             AP:   0.3830  -------
# -------  Class: bottle           AP:   0.1819  -------
# -------  Class: bus              AP:   0.2243  -------
# -------  Class: car              AP:   0.5789  -------
# -------  Class: cat              AP:   0.3843  -------
# -------  Class: chair            AP:   0.4511  -------
# -------  Class: cow              AP:   0.1882  -------
# -------  Class: diningtable      AP:   0.3120  -------
# -------  Class: dog              AP:   0.2721  -------
# -------  Class: horse            AP:   0.5654  -------
# -------  Class: motorbike        AP:   0.5061  -------
# -------  Class: person           AP:   0.7900  -------
# -------  Class: pottedplant      AP:   0.1396  -------
# -------  Class: sheep            AP:   0.1709  -------
# -------  Class: sofa             AP:   0.3275  -------
# -------  Class: train            AP:   0.5088  -------
# -------  Class: tvmonitor        AP:   0.3312  -------
# mAP: 0.3797
# Avg loss: 0.1788354481642063
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 95 is 0.3796875389602353
# Starting epoch number 96
# Loss for Training on Epoch 96 is 0.16453969478607178
# Starting epoch number 97
# Loss for Training on Epoch 97 is 0.16594915091991425
# Starting epoch number 98
# Loss for Training on Epoch 98 is 0.16459153592586517
# Starting epoch number 99
# Loss for Training on Epoch 99 is 0.16586260497570038
# Starting epoch number 100
# Loss for Training on Epoch 100 is 0.16332924365997314
# -------  Class: aeroplane        AP:   0.5589  -------
# -------  Class: bicycle          AP:   0.4061  -------
# -------  Class: bird             AP:   0.2864  -------
# -------  Class: boat             AP:   0.3866  -------
# -------  Class: bottle           AP:   0.1657  -------
# -------  Class: bus              AP:   0.2356  -------
# -------  Class: car              AP:   0.5864  -------
# -------  Class: cat              AP:   0.3584  -------
# -------  Class: chair            AP:   0.4393  -------
# -------  Class: cow              AP:   0.2004  -------
# -------  Class: diningtable      AP:   0.3472  -------
# -------  Class: dog              AP:   0.2665  -------
# -------  Class: horse            AP:   0.5538  -------
# -------  Class: motorbike        AP:   0.4458  -------
# -------  Class: person           AP:   0.7832  -------
# -------  Class: pottedplant      AP:   0.1397  -------
# -------  Class: sheep            AP:   0.1689  -------
# -------  Class: sofa             AP:   0.3212  -------
# -------  Class: train            AP:   0.4727  -------
# -------  Class: tvmonitor        AP:   0.2937  -------
# mAP: 0.3708
# Avg loss: 0.18325981898949698
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 100 is 0.3708333274576957
# Starting epoch number 101
# Loss for Training on Epoch 101 is 0.1649220585823059
# Starting epoch number 102
# Loss for Training on Epoch 102 is 0.16517868638038635
# Starting epoch number 103
# Loss for Training on Epoch 103 is 0.16174907982349396
# Starting epoch number 104
# Loss for Training on Epoch 104 is 0.16251824796199799
# Starting epoch number 105
# Loss for Training on Epoch 105 is 0.16186857223510742
# -------  Class: aeroplane        AP:   0.5847  -------
# -------  Class: bicycle          AP:   0.4220  -------
# -------  Class: bird             AP:   0.2932  -------
# -------  Class: boat             AP:   0.4283  -------
# -------  Class: bottle           AP:   0.1655  -------
# -------  Class: bus              AP:   0.3063  -------
# -------  Class: car              AP:   0.5902  -------
# -------  Class: cat              AP:   0.3649  -------
# -------  Class: chair            AP:   0.4626  -------
# -------  Class: cow              AP:   0.1653  -------
# -------  Class: diningtable      AP:   0.3404  -------
# -------  Class: dog              AP:   0.2747  -------
# -------  Class: horse            AP:   0.5830  -------
# -------  Class: motorbike        AP:   0.5190  -------
# -------  Class: person           AP:   0.7879  -------
# -------  Class: pottedplant      AP:   0.1576  -------
# -------  Class: sheep            AP:   0.1641  -------
# -------  Class: sofa             AP:   0.3080  -------
# -------  Class: train            AP:   0.5459  -------
# -------  Class: tvmonitor        AP:   0.3261  -------
# mAP: 0.3895
# Avg loss: 0.1750133397678534
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 105 is 0.3894883871056164
# Starting epoch number 106
# Loss for Training on Epoch 106 is 0.16015878319740295
# Starting epoch number 107
# Loss for Training on Epoch 107 is 0.159775048494339
# Starting epoch number 108
# Loss for Training on Epoch 108 is 0.16224491596221924
# Starting epoch number 109
# Loss for Training on Epoch 109 is 0.1612328588962555
# Starting epoch number 110
# Loss for Training on Epoch 110 is 0.1559014469385147
# -------  Class: aeroplane        AP:   0.6058  -------
# -------  Class: bicycle          AP:   0.3971  -------
# -------  Class: bird             AP:   0.3149  -------
# -------  Class: boat             AP:   0.4078  -------
# -------  Class: bottle           AP:   0.1797  -------
# -------  Class: bus              AP:   0.2965  -------
# -------  Class: car              AP:   0.6219  -------
# -------  Class: cat              AP:   0.3631  -------
# -------  Class: chair            AP:   0.4808  -------
# -------  Class: cow              AP:   0.1940  -------
# -------  Class: diningtable      AP:   0.3577  -------
# -------  Class: dog              AP:   0.2933  -------
# -------  Class: horse            AP:   0.5597  -------
# -------  Class: motorbike        AP:   0.5297  -------
# -------  Class: person           AP:   0.7934  -------
# -------  Class: pottedplant      AP:   0.1949  -------
# -------  Class: sheep            AP:   0.2104  -------
# -------  Class: sofa             AP:   0.3210  -------
# -------  Class: train            AP:   0.5819  -------
# -------  Class: tvmonitor        AP:   0.3613  -------
# mAP: 0.4032
# Avg loss: 0.17459045197719184
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 110 is 0.40324871547577884
# Starting epoch number 111
# Loss for Training on Epoch 111 is 0.15771037340164185
# Starting epoch number 112
# Loss for Training on Epoch 112 is 0.15751639008522034
# Starting epoch number 113
# Loss for Training on Epoch 113 is 0.15832798182964325
# Starting epoch number 114
# Loss for Training on Epoch 114 is 0.15722031891345978
# Starting epoch number 115
# Loss for Training on Epoch 115 is 0.16006337106227875
# -------  Class: aeroplane        AP:   0.5548  -------
# -------  Class: bicycle          AP:   0.3938  -------
# -------  Class: bird             AP:   0.3117  -------
# -------  Class: boat             AP:   0.3851  -------
# -------  Class: bottle           AP:   0.1436  -------
# -------  Class: bus              AP:   0.3136  -------
# -------  Class: car              AP:   0.5940  -------
# -------  Class: cat              AP:   0.3429  -------
# -------  Class: chair            AP:   0.4549  -------
# -------  Class: cow              AP:   0.1788  -------
# -------  Class: diningtable      AP:   0.3050  -------
# -------  Class: dog              AP:   0.3050  -------
# -------  Class: horse            AP:   0.5450  -------
# -------  Class: motorbike        AP:   0.5168  -------
# -------  Class: person           AP:   0.7760  -------
# -------  Class: pottedplant      AP:   0.1722  -------
# -------  Class: sheep            AP:   0.1858  -------
# -------  Class: sofa             AP:   0.3556  -------
# -------  Class: train            AP:   0.5574  -------
# -------  Class: tvmonitor        AP:   0.3281  -------
# mAP: 0.3860
# Avg loss: 0.18192895654684457
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 115 is 0.38599226084967847
# Starting epoch number 116
# Loss for Training on Epoch 116 is 0.15648134052753448
# Starting epoch number 117
# Loss for Training on Epoch 117 is 0.1572033166885376
# Starting epoch number 118
# Loss for Training on Epoch 118 is 0.15687477588653564
# Starting epoch number 119
# Loss for Training on Epoch 119 is 0.15598765015602112
# Starting epoch number 120
# Loss for Training on Epoch 120 is 0.15500964224338531
# -------  Class: aeroplane        AP:   0.6078  -------
# -------  Class: bicycle          AP:   0.3922  -------
# -------  Class: bird             AP:   0.3259  -------
# -------  Class: boat             AP:   0.4576  -------
# -------  Class: bottle           AP:   0.1783  -------
# -------  Class: bus              AP:   0.3145  -------
# -------  Class: car              AP:   0.6028  -------
# -------  Class: cat              AP:   0.3533  -------
# -------  Class: chair            AP:   0.4836  -------
# -------  Class: cow              AP:   0.2166  -------
# -------  Class: diningtable      AP:   0.3807  -------
# -------  Class: dog              AP:   0.2742  -------
# -------  Class: horse            AP:   0.5617  -------
# -------  Class: motorbike        AP:   0.4757  -------
# -------  Class: person           AP:   0.8020  -------
# -------  Class: pottedplant      AP:   0.1377  -------
# -------  Class: sheep            AP:   0.1680  -------
# -------  Class: sofa             AP:   0.3212  -------
# -------  Class: train            AP:   0.5663  -------
# -------  Class: tvmonitor        AP:   0.3037  -------
# mAP: 0.3962
# Avg loss: 0.17982182365197402
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 120 is 0.39619707692499795
# Starting epoch number 121
# Loss for Training on Epoch 121 is 0.1546856313943863
# Starting epoch number 122
# Loss for Training on Epoch 122 is 0.1571812778711319
# Starting epoch number 123
# Loss for Training on Epoch 123 is 0.1528109610080719
# Starting epoch number 124
# Loss for Training on Epoch 124 is 0.15532268583774567
# Starting epoch number 125
# Loss for Training on Epoch 125 is 0.15652614831924438
# -------  Class: aeroplane        AP:   0.6212  -------
# -------  Class: bicycle          AP:   0.4396  -------
# -------  Class: bird             AP:   0.3196  -------
# -------  Class: boat             AP:   0.4518  -------
# -------  Class: bottle           AP:   0.1464  -------
# -------  Class: bus              AP:   0.2920  -------
# -------  Class: car              AP:   0.6146  -------
# -------  Class: cat              AP:   0.3397  -------
# -------  Class: chair            AP:   0.4667  -------
# -------  Class: cow              AP:   0.1642  -------
# -------  Class: diningtable      AP:   0.3294  -------
# -------  Class: dog              AP:   0.2892  -------
# -------  Class: horse            AP:   0.5551  -------
# -------  Class: motorbike        AP:   0.5122  -------
# -------  Class: person           AP:   0.7812  -------
# -------  Class: pottedplant      AP:   0.1616  -------
# -------  Class: sheep            AP:   0.2017  -------
# -------  Class: sofa             AP:   0.3459  -------
# -------  Class: train            AP:   0.5237  -------
# -------  Class: tvmonitor        AP:   0.3790  -------
# mAP: 0.3967
# Avg loss: 0.17751171812415123
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 125 is 0.3967395678208923
# Starting epoch number 126
# Loss for Training on Epoch 126 is 0.15433140099048615
# Starting epoch number 127
# Loss for Training on Epoch 127 is 0.15567444264888763
# Starting epoch number 128
# Loss for Training on Epoch 128 is 0.14982955157756805
# Starting epoch number 129
# Loss for Training on Epoch 129 is 0.15388281643390656
# Starting epoch number 130
# Loss for Training on Epoch 130 is 0.15432167053222656
# -------  Class: aeroplane        AP:   0.5994  -------
# -------  Class: bicycle          AP:   0.4473  -------
# -------  Class: bird             AP:   0.3055  -------
# -------  Class: boat             AP:   0.3880  -------
# -------  Class: bottle           AP:   0.1598  -------
# -------  Class: bus              AP:   0.3568  -------
# -------  Class: car              AP:   0.6122  -------
# -------  Class: cat              AP:   0.3127  -------
# -------  Class: chair            AP:   0.4694  -------
# -------  Class: cow              AP:   0.2055  -------
# -------  Class: diningtable      AP:   0.3478  -------
# -------  Class: dog              AP:   0.2672  -------
# -------  Class: horse            AP:   0.5922  -------
# -------  Class: motorbike        AP:   0.5305  -------
# -------  Class: person           AP:   0.7867  -------
# -------  Class: pottedplant      AP:   0.1656  -------
# -------  Class: sheep            AP:   0.1810  -------
# -------  Class: sofa             AP:   0.3243  -------
# -------  Class: train            AP:   0.5532  -------
# -------  Class: tvmonitor        AP:   0.3795  -------
# mAP: 0.3992
# Avg loss: 0.17711749309912705
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 130 is 0.3992356623207286
# Starting epoch number 131
# Loss for Training on Epoch 131 is 0.15214286744594574
# Starting epoch number 132
# Loss for Training on Epoch 132 is 0.1537681519985199
# Starting epoch number 133
# Loss for Training on Epoch 133 is 0.14973194897174835
# Starting epoch number 134
# Loss for Training on Epoch 134 is 0.14874601364135742
# Starting epoch number 135
# Loss for Training on Epoch 135 is 0.15202696621418
# -------  Class: aeroplane        AP:   0.5867  -------
# -------  Class: bicycle          AP:   0.4116  -------
# -------  Class: bird             AP:   0.3330  -------
# -------  Class: boat             AP:   0.4064  -------
# -------  Class: bottle           AP:   0.1690  -------
# -------  Class: bus              AP:   0.3147  -------
# -------  Class: car              AP:   0.5744  -------
# -------  Class: cat              AP:   0.3160  -------
# -------  Class: chair            AP:   0.4214  -------
# -------  Class: cow              AP:   0.1800  -------
# -------  Class: diningtable      AP:   0.3238  -------
# -------  Class: dog              AP:   0.2937  -------
# -------  Class: horse            AP:   0.5346  -------
# -------  Class: motorbike        AP:   0.3934  -------
# -------  Class: person           AP:   0.7776  -------
# -------  Class: pottedplant      AP:   0.1840  -------
# -------  Class: sheep            AP:   0.2081  -------
# -------  Class: sofa             AP:   0.2903  -------
# -------  Class: train            AP:   0.5921  -------
# -------  Class: tvmonitor        AP:   0.3348  -------
# mAP: 0.3823
# Avg loss: 0.19054384243029815
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 135 is 0.3822787120797698
# Starting epoch number 136
# Loss for Training on Epoch 136 is 0.15340763330459595
# Starting epoch number 137
# Loss for Training on Epoch 137 is 0.15389932692050934
# Starting epoch number 138
# Loss for Training on Epoch 138 is 0.1481807380914688
# Starting epoch number 139
# Loss for Training on Epoch 139 is 0.14875859022140503
# Starting epoch number 140
# Loss for Training on Epoch 140 is 0.14924292266368866
# -------  Class: aeroplane        AP:   0.6153  -------
# -------  Class: bicycle          AP:   0.4669  -------
# -------  Class: bird             AP:   0.3485  -------
# -------  Class: boat             AP:   0.3850  -------
# -------  Class: bottle           AP:   0.1945  -------
# -------  Class: bus              AP:   0.3168  -------
# -------  Class: car              AP:   0.5943  -------
# -------  Class: cat              AP:   0.3666  -------
# -------  Class: chair            AP:   0.4611  -------
# -------  Class: cow              AP:   0.2033  -------
# -------  Class: diningtable      AP:   0.3787  -------
# -------  Class: dog              AP:   0.3102  -------
# -------  Class: horse            AP:   0.5762  -------
# -------  Class: motorbike        AP:   0.5144  -------
# -------  Class: person           AP:   0.8039  -------
# -------  Class: pottedplant      AP:   0.1759  -------
# -------  Class: sheep            AP:   0.1739  -------
# -------  Class: sofa             AP:   0.3050  -------
# -------  Class: train            AP:   0.5321  -------
# -------  Class: tvmonitor        AP:   0.3742  -------
# mAP: 0.4048
# Avg loss: 0.17869987988319153
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 140 is 0.4048474727796231
# Starting epoch number 141
# Loss for Training on Epoch 141 is 0.1496322900056839
# Starting epoch number 142
# Loss for Training on Epoch 142 is 0.14615283906459808
# Starting epoch number 143
# Loss for Training on Epoch 143 is 0.15177685022354126
# Starting epoch number 144
# Loss for Training on Epoch 144 is 0.14875881373882294
# Starting epoch number 145
# Loss for Training on Epoch 145 is 0.14830011129379272
# -------  Class: aeroplane        AP:   0.5540  -------
# -------  Class: bicycle          AP:   0.4485  -------
# -------  Class: bird             AP:   0.3263  -------
# -------  Class: boat             AP:   0.4344  -------
# -------  Class: bottle           AP:   0.1377  -------
# -------  Class: bus              AP:   0.3090  -------
# -------  Class: car              AP:   0.6141  -------
# -------  Class: cat              AP:   0.3140  -------
# -------  Class: chair            AP:   0.4652  -------
# -------  Class: cow              AP:   0.1800  -------
# -------  Class: diningtable      AP:   0.3499  -------
# -------  Class: dog              AP:   0.2944  -------
# -------  Class: horse            AP:   0.5940  -------
# -------  Class: motorbike        AP:   0.4895  -------
# -------  Class: person           AP:   0.7725  -------
# -------  Class: pottedplant      AP:   0.1949  -------
# -------  Class: sheep            AP:   0.1644  -------
# -------  Class: sofa             AP:   0.3142  -------
# -------  Class: train            AP:   0.5654  -------
# -------  Class: tvmonitor        AP:   0.3288  -------
# mAP: 0.3925
# Avg loss: 0.18705657258247718
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 145 is 0.3925477928112914
# Starting epoch number 146
# Loss for Training on Epoch 146 is 0.1463354527950287
# Starting epoch number 147
# Loss for Training on Epoch 147 is 0.14870448410511017
# Starting epoch number 148
# Loss for Training on Epoch 148 is 0.14357000589370728
# Starting epoch number 149
# Loss for Training on Epoch 149 is 0.14779342710971832
# Starting epoch number 150
# Loss for Training on Epoch 150 is 0.14645610749721527
# -------  Class: aeroplane        AP:   0.6103  -------
# -------  Class: bicycle          AP:   0.4474  -------
# -------  Class: bird             AP:   0.3492  -------
# -------  Class: boat             AP:   0.4299  -------
# -------  Class: bottle           AP:   0.1596  -------
# -------  Class: bus              AP:   0.3542  -------
# -------  Class: car              AP:   0.6007  -------
# -------  Class: cat              AP:   0.3593  -------
# -------  Class: chair            AP:   0.4732  -------
# -------  Class: cow              AP:   0.2129  -------
# -------  Class: diningtable      AP:   0.3529  -------
# -------  Class: dog              AP:   0.2870  -------
# -------  Class: horse            AP:   0.5769  -------
# -------  Class: motorbike        AP:   0.5855  -------
# -------  Class: person           AP:   0.7891  -------
# -------  Class: pottedplant      AP:   0.1851  -------
# -------  Class: sheep            AP:   0.1990  -------
# -------  Class: sofa             AP:   0.3443  -------
# -------  Class: train            AP:   0.5915  -------
# -------  Class: tvmonitor        AP:   0.3782  -------
# mAP: 0.4143
# Avg loss: 0.17831684859135213
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 150 is 0.41431196605436504

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print(mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.5853  -------
# -------  Class: bicycle          AP:   0.3948  -------
# -------  Class: bird             AP:   0.3162  -------
# -------  Class: boat             AP:   0.3650  -------
# -------  Class: bottle           AP:   0.1579  -------
# -------  Class: bus              AP:   0.3160  -------
# -------  Class: car              AP:   0.6146  -------
# -------  Class: cat              AP:   0.3580  -------
# -------  Class: chair            AP:   0.4145  -------
# -------  Class: cow              AP:   0.1921  -------
# -------  Class: diningtable      AP:   0.2587  -------
# -------  Class: dog              AP:   0.2990  -------
# -------  Class: horse            AP:   0.6802  -------
# -------  Class: motorbike        AP:   0.5494  -------
# -------  Class: person           AP:   0.8033  -------
# -------  Class: pottedplant      AP:   0.2133  -------
# -------  Class: sheep            AP:   0.3216  -------
# -------  Class: sofa             AP:   0.3264  -------
# -------  Class: train            AP:   0.5123  -------
# -------  Class: tvmonitor        AP:   0.3114  -------
# mAP: 0.3995
# Avg loss: 0.1766747386231051
# 0.3995088353656625

# %%
torch.save(classifier.state_dict(), './voc_my_best_classifier.pth')
output_submission_csv('my_solution.csv', test_aps)

# %%
device
# Out:
# device(type='cuda', index=1)
