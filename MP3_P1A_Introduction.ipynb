# %% [markdown]
# # Assignment 3 Part 1A Introduction: Multi-label Image Classification

# %%
from google.colab import drive
drive.mount('/content/gdrive/',force_remount=True)

import sys
sys.path.append('/content/gdrive/My Drive/assignment3_p1_starterkit')

import os
import numpy as np
import torch
import torch.nn as nn
import torchvision

from torchvision import transforms
from sklearn.metrics import average_precision_score
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt
from kaggle_submission import output_submission_csv
from classifier import SimpleClassifier, Classifier#, AlexNet
from voc_dataloader import VocDataset, VOC_CLASSES

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# Out:
# Mounted at /content/gdrive/

# %%
# !pip install torch==1.5.1+cu101 torchvision==0.6.1+cu101 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.5.1+cu101
#   Downloading https://download.pytorch.org/whl/cu101/torch-1.5.1%2Bcu101-cp36-cp36m-linux_x86_64.whl (704.4MB)
#      |████████████████████████████████| 704.4MB 25kB/s
# Collecting torchvision==0.6.1+cu101
#   Downloading https://download.pytorch.org/whl/cu101/torchvision-0.6.1%2Bcu101-cp36-cp36m-linux_x86_64.whl (6.6MB)
#      |████████████████████████████████| 6.6MB 3.1MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1+cu101) (1.18.5)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch==1.5.1+cu101) (0.16.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.6.1+cu101) (7.0.0)
# Installing collected packages: torch, torchvision
#   Found existing installation: torch 1.6.0+cu101
#     Uninstalling torch-1.6.0+cu101:
#       Successfully uninstalled torch-1.6.0+cu101
#     Uninstalling torchvision-0.7.0+cu101:
#       Successfully uninstalled torchvision-0.7.0+cu101
# Successfully installed torch-1.5.1+cu101 torchvision-0.6.1+cu101

# %%
import os
os.chdir('/content/gdrive/My Drive/assignment3_p1_starterkit')

# %%
#!bash download_data.sh

# %%
import shutil 
shutil.copyfile("VOCtrainval_06-Nov-2007.tar.1", "/content/VOCtrainval_06-Nov-2007.tar.1")
# !tar -xf "/content/VOCtrainval_06-Nov-2007.tar.1" -C "/content/" 
shutil.move("/content/VOCdevkit/", "/content/VOCdevkit_2007")

#shutil.copyfile("VOCdevkit_2007/VOC2007test", "/content/VOC2007test")
#!tar -xf "/content/VOCtest_06-Nov-2007.tar" -C "/content/" 
#shutil.move("/content/VOCdevkit/VOC2007", "/content/VOCdevkit_2007/VOC2007test")
# Out:
# '/content/VOCdevkit_2007'

# %% [markdown]
# # Multi-label Classification
# In this assignment, you train a classifier to do multi-label classificaton on the PASCAL VOC 2007 dataset. The dataset has 20 different class which can appear in any given image. Your classifier will predict whether each class appears in an image. This task is slightly different from exclusive multiclass classification like the ImageNet competition where only a single most appropriate class is predicted for an image.
#
# ## Part 1A
# You will use this notebook to warm up with pytorch and the code+dataset that we will use for assignment3.
#
# ### What to do
# In part 1A, You are asked to run below experiments. You don't need to change hyperparameters for this Part 1A's experiments. (the following code provides everything that you will need.)
# 1. to train a simple network (defined in ```classifiers.py```)
# 2. to train the AlexNet (PyTorch built-in)
#     - from scratch
#     - finetuning AlexNet pretrained on ImageNet
#
#
#
# ### What to submit
# We ask you to run the following code and report the results in your homework submission. You may want to leverage this part 1A get yourself familiar with PyTorch.
#
# You will the need the numbers and plots this notebook outputs for reports, but you are not required to submit this notebook as a printed pdf.

# %% [markdown]
# ## Reading Pascal Data

# %% [markdown]
# ### Loading Training Data

# %% [markdown]
# In the following cell we will load the training data and also apply some transforms to the data.

# %%
# Transforms applied to the training data
normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                     std= [0.229, 0.224, 0.225])

train_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.RandomResizedCrop(227),
            transforms.CenterCrop(227),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ToTensor(),
            normalize
        ])

# %%
ds_train = VocDataset('/content/VOCdevkit_2007/VOC2007','train',train_transform)

# %% [markdown]
# ### Loading Validation Data

# %% [markdown]
# We will load the test data for the PASCAL VOC 2007 dataset. Do __NOT__ add data augmentation transforms to validation data.

# %%
# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            #transforms.RandomResizedCrop(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            #transforms.RandomHorizontalFlip(p=0.5),
            normalize
        ])

# %%
ds_val = VocDataset('/content/VOCdevkit_2007/VOC2007/','val',test_transform)

# %% [markdown]
# ### Visualizing the Data
#
# PASCAL VOC has bounding box annotations in addition to class labels. Use the following code to visualize some random examples and corresponding annotations from the train set.

# %%
for i in range(5):
    idx = np.random.randint(0, len(ds_train.names)+1)
    _imgpath = os.path.join('/content/VOCdevkit_2007/VOC2007/', 'JPEGImages', ds_train.names[idx]+'.jpg')
    img = Image.open(_imgpath).convert('RGB')
    draw = ImageDraw.Draw(img)
    for j in range(len(ds_train.box_indices[idx])):
        obj = ds_train.box_indices[idx][j]
        draw.rectangle(list(obj), outline=(255,0,0))
        draw.text(list(obj[0:2]), ds_train.classes[ds_train.label_order[idx][j]], fill=(0,255,0))
    plt.figure(figsize = (10,10))
    plt.imshow(np.array(img))

# %% [markdown]
# # Classification

# %%
# declare what device to use: gpu/cpu
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda', index=0)

# %%
train_loader = torch.utils.data.DataLoader(dataset=ds_train,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1,drop_last=True)

# %%
val_loader = torch.utils.data.DataLoader(dataset=ds_val,
                                               batch_size=50, 
                                               shuffle=True,
                                               num_workers=1,drop_last=True)

# %%
train_loader

# %%
def train_classifier(train_loader, classifier, criterion, optimizer):
    classifier.train()
    loss_ = 0.0
    losses = []
    for i, (images, labels, _) in enumerate(train_loader):
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(images)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        losses.append(loss)
    print('yes')
    return torch.stack(losses).mean().item()

# %%
def test_classifier(test_loader, classifier, criterion, print_ind_classes=True, print_total=True):
    classifier.eval()
    losses = []
    with torch.no_grad():
        y_true = np.zeros((0,21))
        y_score = np.zeros((0,21))
        for i, (images, labels, _) in enumerate(test_loader):
            images, labels = images.to(device), labels.to(device)
            logits = classifier(images)
            y_true = np.concatenate((y_true, labels.cpu().numpy()), axis=0)
            y_score = np.concatenate((y_score, logits.cpu().numpy()), axis=0)
            loss = criterion(logits, labels)
            losses.append(loss.item())
        aps = []
        # ignore first class which is background
        for i in range(1, y_true.shape[1]):
            ap = average_precision_score(y_true[:, i], y_score[:, i])
            if print_ind_classes:
                print('-------  Class: {:<12}     AP: {:>8.4f}  -------'.format(VOC_CLASSES[i], ap))
            aps.append(ap)
        
        mAP = np.mean(aps)
        test_loss = np.mean(losses)
        if print_total:
            print('mAP: {0:.4f}'.format(mAP))
            print('Avg loss: {}'.format(test_loss))
        
    return mAP, test_loss, aps

# %%
# plot functions
def plot_losses(train, val, test_frequency, num_epochs):
    plt.plot(train, label="train")
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, val, label="val")
    plt.title("Loss Plot")
    plt.ylabel("Loss")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()
    
def plot_mAP(train, val, test_frequency, num_epochs):
    indices = [i for i in range(num_epochs) if ((i+1)%test_frequency == 0 or i ==0)]
    plt.plot(indices, train, label="train")
    plt.plot(indices, val, label="val")
    plt.title("mAP Plot")
    plt.ylabel("mAP")
    plt.xlabel("Epoch")
    plt.legend()
    plt.show()

# %% [markdown]
# ## Training the network
#
# The simple network you are given as is will allow you to reach around 0.15-0.2 mAP. In this project, you will find ways to design a better network. Save plots and final test mAP scores as you will be adding these to the writeup.

# %%
def train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency=5):
    train_losses = []
    train_mAPs = []
    val_losses = []
    val_mAPs = []

    for epoch in range(1,num_epochs+1):
        print("Starting epoch number " + str(epoch))
        train_loss = train_classifier(train_loader, classifier, criterion, optimizer)
        train_losses.append(train_loss)
        print("Loss for Training on Epoch " +str(epoch) + " is "+ str(train_loss))
        if(epoch%test_frequency==0 or epoch==1):
            mAP_train, _, _ = test_classifier(train_loader, classifier, criterion, False, False)
            train_mAPs.append(mAP_train)
            mAP_val, val_loss, _ = test_classifier(val_loader, classifier, criterion)
            print('Evaluating classifier')
            print("Mean Precision Score for Testing on Epoch " +str(epoch) + " is "+ str(mAP_val))
            val_losses.append(val_loss)
            val_mAPs.append(mAP_val)
    
    return classifier, train_losses, val_losses, train_mAPs, val_mAPs

# %%
classifier = SimpleClassifier().to(device)
# classifier = Classifier().to(device)
# You can can use this function to reload a network you have already saved previously
#classifier.load_state_dict(torch.load('voc_classifier.pth'))

# %%
criterion = nn.MultiLabelSoftMarginLoss()
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.1, momentum=0.9) 
# torch.optim.lr_scheduler.StepLR(optimizer, 50, gamma=0.001, last_epoch=-1)

# optimizer = torch.optim.Adam(classifier.parameters(), lr=0.01, betas=(0.9, 0.999),weight_decay=0.0001)

# %%
# Training the Classifier
num_epochs = 20
test_frequency = 5

classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# yes
# Loss for Training on Epoch 1 is 0.23798952996730804
# -------  Class: aeroplane        AP:   0.0376  -------
# -------  Class: bicycle          AP:   0.0388  -------
# -------  Class: bird             AP:   0.0688  -------
# -------  Class: boat             AP:   0.0298  -------
# -------  Class: bottle           AP:   0.0452  -------
# -------  Class: bus              AP:   0.0296  -------
# -------  Class: car              AP:   0.1224  -------
# -------  Class: cat              AP:   0.0941  -------
# -------  Class: chair            AP:   0.1397  -------
# -------  Class: cow              AP:   0.0356  -------
# -------  Class: diningtable      AP:   0.0612  -------
# -------  Class: dog              AP:   0.1056  -------
# -------  Class: horse            AP:   0.0602  -------
# -------  Class: motorbike        AP:   0.0443  -------
# -------  Class: person           AP:   0.3884  -------
# -------  Class: pottedplant      AP:   0.0503  -------
# -------  Class: sheep            AP:   0.0297  -------
# -------  Class: sofa             AP:   0.1052  -------
# -------  Class: train            AP:   0.0537  -------
# -------  Class: tvmonitor        AP:   0.0665  -------
# mAP: 0.0803
# Avg loss: 0.23401026040315628
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.08033042761145556
# Starting epoch number 2
# yes
# Loss for Training on Epoch 2 is 0.23764342069625854
# Starting epoch number 3
# yes
# Loss for Training on Epoch 3 is 0.2369566261768341
# Starting epoch number 4
# yes
# Loss for Training on Epoch 4 is 0.23736827075481415
# Starting epoch number 5
# yes
# Loss for Training on Epoch 5 is 0.23697108030319214
# -------  Class: aeroplane        AP:   0.1746  -------
# -------  Class: bicycle          AP:   0.0448  -------
# -------  Class: bird             AP:   0.0598  -------
# -------  Class: boat             AP:   0.0719  -------
# -------  Class: bottle           AP:   0.0342  -------
# -------  Class: bus              AP:   0.0457  -------
# -------  Class: car              AP:   0.1586  -------
# -------  Class: cat              AP:   0.0636  -------
# -------  Class: chair            AP:   0.1089  -------
# -------  Class: cow              AP:   0.0445  -------
# -------  Class: diningtable      AP:   0.0417  -------
# -------  Class: dog              AP:   0.0827  -------
# -------  Class: horse            AP:   0.0821  -------
# -------  Class: motorbike        AP:   0.0425  -------
# -------  Class: person           AP:   0.3739  -------
# -------  Class: pottedplant      AP:   0.0458  -------
# -------  Class: sheep            AP:   0.0601  -------
# -------  Class: sofa             AP:   0.0779  -------
# -------  Class: train            AP:   0.0925  -------
# -------  Class: tvmonitor        AP:   0.0478  -------
# mAP: 0.0877
# Avg loss: 0.23350727200508117
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08767908642051722
# Starting epoch number 6
# yes
# Loss for Training on Epoch 6 is 0.23676013946533203
# Starting epoch number 7
# yes
# Loss for Training on Epoch 7 is 0.23497578501701355
# Starting epoch number 8
# yes
# Loss for Training on Epoch 8 is 0.23175521194934845
# Starting epoch number 9
# yes
# Loss for Training on Epoch 9 is 0.23046424984931946
# Starting epoch number 10
# yes
# Loss for Training on Epoch 10 is 0.2303169071674347
# -------  Class: aeroplane        AP:   0.3387  -------
# -------  Class: bicycle          AP:   0.0717  -------
# -------  Class: bird             AP:   0.0819  -------
# -------  Class: boat             AP:   0.1712  -------
# -------  Class: bottle           AP:   0.0719  -------
# -------  Class: bus              AP:   0.0723  -------
# -------  Class: car              AP:   0.2040  -------
# -------  Class: cat              AP:   0.1010  -------
# -------  Class: chair            AP:   0.1496  -------
# -------  Class: cow              AP:   0.0459  -------
# -------  Class: diningtable      AP:   0.1045  -------
# -------  Class: dog              AP:   0.1362  -------
# -------  Class: horse            AP:   0.0728  -------
# -------  Class: motorbike        AP:   0.0494  -------
# -------  Class: person           AP:   0.4603  -------
# -------  Class: pottedplant      AP:   0.0694  -------
# -------  Class: sheep            AP:   0.0334  -------
# -------  Class: sofa             AP:   0.1267  -------
# -------  Class: train            AP:   0.1492  -------
# -------  Class: tvmonitor        AP:   0.0646  -------
# mAP: 0.1287
# Avg loss: 0.225627778172493
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.12874113338433826
# Starting epoch number 11
# yes
# Loss for Training on Epoch 11 is 0.22834399342536926
# Starting epoch number 12
# yes
# Loss for Training on Epoch 12 is 0.2288665771484375
# Starting epoch number 13
# yes
# Loss for Training on Epoch 13 is 0.22663195431232452
# Starting epoch number 14
# yes
# Loss for Training on Epoch 14 is 0.2261429876089096
# Starting epoch number 15
# yes
# Loss for Training on Epoch 15 is 0.22695201635360718
# -------  Class: aeroplane        AP:   0.3004  -------
# -------  Class: bicycle          AP:   0.0562  -------
# -------  Class: bird             AP:   0.0810  -------
# -------  Class: boat             AP:   0.2459  -------
# -------  Class: bottle           AP:   0.1057  -------
# -------  Class: bus              AP:   0.0678  -------
# -------  Class: car              AP:   0.2610  -------
# -------  Class: cat              AP:   0.1366  -------
# -------  Class: chair            AP:   0.1899  -------
# -------  Class: cow              AP:   0.0560  -------
# -------  Class: diningtable      AP:   0.1762  -------
# -------  Class: dog              AP:   0.1254  -------
# -------  Class: horse            AP:   0.0894  -------
# -------  Class: motorbike        AP:   0.0529  -------
# -------  Class: person           AP:   0.4932  -------
# -------  Class: pottedplant      AP:   0.0692  -------
# -------  Class: sheep            AP:   0.0387  -------
# -------  Class: sofa             AP:   0.1385  -------
# -------  Class: train            AP:   0.1529  -------
# -------  Class: tvmonitor        AP:   0.0677  -------
# mAP: 0.1452
# Avg loss: 0.22460741460323333
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.14522545197244907
# Starting epoch number 16
# yes
# Loss for Training on Epoch 16 is 0.22446925938129425
# Starting epoch number 17
# yes
# Loss for Training on Epoch 17 is 0.22328917682170868
# Starting epoch number 18
# yes
# Loss for Training on Epoch 18 is 0.22192001342773438
# Starting epoch number 19
# yes
# Loss for Training on Epoch 19 is 0.21950414776802063
# Starting epoch number 20
# yes
# Loss for Training on Epoch 20 is 0.2185143679380417
# -------  Class: aeroplane        AP:   0.3242  -------
# -------  Class: bicycle          AP:   0.0789  -------
# -------  Class: bird             AP:   0.1314  -------
# -------  Class: boat             AP:   0.2793  -------
# -------  Class: bottle           AP:   0.1301  -------
# -------  Class: bus              AP:   0.1128  -------
# -------  Class: car              AP:   0.3897  -------
# -------  Class: cat              AP:   0.1569  -------
# -------  Class: chair            AP:   0.2467  -------
# -------  Class: cow              AP:   0.0709  -------
# -------  Class: diningtable      AP:   0.2143  -------
# -------  Class: dog              AP:   0.1350  -------
# -------  Class: horse            AP:   0.1302  -------
# -------  Class: motorbike        AP:   0.1151  -------
# -------  Class: person           AP:   0.5708  -------
# -------  Class: pottedplant      AP:   0.0800  -------
# -------  Class: sheep            AP:   0.0741  -------
# -------  Class: sofa             AP:   0.1615  -------
# -------  Class: train            AP:   0.1737  -------
# -------  Class: tvmonitor        AP:   0.0923  -------
# mAP: 0.1834
# Avg loss: 0.21578054875135422
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.18338300240515473

# %%
# torch.cuda.empty_cache()

# %%
# Compare train and validation metrics
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
# Save the clssifier network
# Suggestion: you can save checkpoints of your network during training and reload them later
torch.save(classifier.state_dict(), './voc_simple_classifier.pth')

# %% [markdown]
# # Evaluate on test set

# %%
ds_test = VocDataset('/content/gdrive/My Drive/assignment3_p1_starterkit/VOCdevkit_2007/VOC2007test/','test', test_transform)

test_loader = torch.utils.data.DataLoader(dataset=ds_test,
                                               batch_size=50, 
                                               shuffle=False,
                                               num_workers=1)

# Transforms applied to the testing data
test_transform = transforms.Compose([
            transforms.Resize(227),
            transforms.CenterCrop(227),
            transforms.ToTensor(),
            normalize,
        ])

mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
# Out:
# -------  Class: aeroplane        AP:   0.3258  -------
# -------  Class: bicycle          AP:   0.0720  -------
# -------  Class: bird             AP:   0.1298  -------
# -------  Class: boat             AP:   0.2053  -------
# -------  Class: bottle           AP:   0.1126  -------
# -------  Class: bus              AP:   0.0778  -------
# -------  Class: car              AP:   0.4392  -------
# -------  Class: cat              AP:   0.1441  -------
# -------  Class: chair            AP:   0.2480  -------
# -------  Class: cow              AP:   0.1103  -------
# -------  Class: diningtable      AP:   0.1753  -------
# -------  Class: dog              AP:   0.1430  -------
# -------  Class: horse            AP:   0.1062  -------
# -------  Class: motorbike        AP:   0.0926  -------
# -------  Class: person           AP:   0.5961  -------
# -------  Class: pottedplant      AP:   0.0866  -------
# -------  Class: sheep            AP:   0.1157  -------
# -------  Class: sofa             AP:   0.1612  -------
# -------  Class: train            AP:   0.1953  -------
# -------  Class: tvmonitor        AP:   0.0920  -------
# mAP: 0.1814
# Avg loss: 0.21090251877903937

# %%
output_submission_csv('my_solution.csv', test_aps)

# %% [markdown]
# # AlexNet Baselines (From Scratch)

# %% [markdown]
# AlexNet was one of the earliest deep learning models to have success in classification. In this section we will be running classification with AlexNet as a baseline. Furthermore, we will run an ImageNet-pretrained AlexNet to observe the impact of well-trained features. Save plots and final test mAP scores as you will be adding these to the writeup.

# %% [markdown]
# ## Running AlexNet
#
# In this section, we train AlexNet from scratch using the same hyperparameters as our previous experiment.

# %%
num_epochs = 20
test_frequency = 5

# Change classifier to AlexNet
classifier = torchvision.models.alexnet(pretrained=False)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)

criterion = nn.MultiLabelSoftMarginLoss()

optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# yes
# Loss for Training on Epoch 1 is 0.6027382612228394
# -------  Class: aeroplane        AP:   0.1742  -------
# -------  Class: bicycle          AP:   0.0489  -------
# -------  Class: bird             AP:   0.1018  -------
# -------  Class: boat             AP:   0.1524  -------
# -------  Class: bottle           AP:   0.0365  -------
# -------  Class: bus              AP:   0.0327  -------
# -------  Class: car              AP:   0.1160  -------
# -------  Class: cat              AP:   0.0806  -------
# -------  Class: chair            AP:   0.1028  -------
# -------  Class: cow              AP:   0.0345  -------
# -------  Class: diningtable      AP:   0.0446  -------
# -------  Class: dog              AP:   0.1033  -------
# -------  Class: horse            AP:   0.0468  -------
# -------  Class: motorbike        AP:   0.0357  -------
# -------  Class: person           AP:   0.4832  -------
# -------  Class: pottedplant      AP:   0.0426  -------
# -------  Class: sheep            AP:   0.0341  -------
# -------  Class: sofa             AP:   0.0781  -------
# -------  Class: train            AP:   0.0426  -------
# -------  Class: tvmonitor        AP:   0.0470  -------
# mAP: 0.0919
# Avg loss: 0.2897162339091301
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.09191782226185821
# Starting epoch number 2
# yes
# Loss for Training on Epoch 2 is 0.2547684907913208
# Starting epoch number 3
# yes
# Loss for Training on Epoch 3 is 0.243783637881279
# Starting epoch number 4
# yes
# Loss for Training on Epoch 4 is 0.24363335967063904
# Starting epoch number 5
# yes
# Loss for Training on Epoch 5 is 0.24354392290115356
# -------  Class: aeroplane        AP:   0.0945  -------
# -------  Class: bicycle          AP:   0.0456  -------
# -------  Class: bird             AP:   0.1163  -------
# -------  Class: boat             AP:   0.0986  -------
# -------  Class: bottle           AP:   0.0439  -------
# -------  Class: bus              AP:   0.0293  -------
# -------  Class: car              AP:   0.1124  -------
# -------  Class: cat              AP:   0.0934  -------
# -------  Class: chair            AP:   0.1238  -------
# -------  Class: cow              AP:   0.0344  -------
# -------  Class: diningtable      AP:   0.0555  -------
# -------  Class: dog              AP:   0.1156  -------
# -------  Class: horse            AP:   0.0483  -------
# -------  Class: motorbike        AP:   0.0364  -------
# -------  Class: person           AP:   0.3795  -------
# -------  Class: pottedplant      AP:   0.0460  -------
# -------  Class: sheep            AP:   0.0378  -------
# -------  Class: sofa             AP:   0.0991  -------
# -------  Class: train            AP:   0.0411  -------
# -------  Class: tvmonitor        AP:   0.0476  -------
# mAP: 0.0849
# Avg loss: 0.24069972097873688
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.08494974236008075
# Starting epoch number 6
# yes
# Loss for Training on Epoch 6 is 0.24220985174179077
# Starting epoch number 7
# yes
# Loss for Training on Epoch 7 is 0.2419455647468567
# Starting epoch number 8
# yes
# Loss for Training on Epoch 8 is 0.24184009432792664
# Starting epoch number 9
# yes
# Loss for Training on Epoch 9 is 0.24132892489433289
# Starting epoch number 10
# yes
# Loss for Training on Epoch 10 is 0.24077585339546204
# -------  Class: aeroplane        AP:   0.0785  -------
# -------  Class: bicycle          AP:   0.0479  -------
# -------  Class: bird             AP:   0.1237  -------
# -------  Class: boat             AP:   0.0856  -------
# -------  Class: bottle           AP:   0.0456  -------
# -------  Class: bus              AP:   0.0303  -------
# -------  Class: car              AP:   0.1215  -------
# -------  Class: cat              AP:   0.0934  -------
# -------  Class: chair            AP:   0.1345  -------
# -------  Class: cow              AP:   0.0342  -------
# -------  Class: diningtable      AP:   0.0600  -------
# -------  Class: dog              AP:   0.1193  -------
# -------  Class: horse            AP:   0.0508  -------
# -------  Class: motorbike        AP:   0.0391  -------
# -------  Class: person           AP:   0.4060  -------
# -------  Class: pottedplant      AP:   0.0497  -------
# -------  Class: sheep            AP:   0.0455  -------
# -------  Class: sofa             AP:   0.1015  -------
# -------  Class: train            AP:   0.0432  -------
# -------  Class: tvmonitor        AP:   0.0516  -------
# mAP: 0.0881
# Avg loss: 0.238303744494915
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.08810150595763411
# Starting epoch number 11
# yes
# Loss for Training on Epoch 11 is 0.2402462363243103
# Starting epoch number 12
# yes
# Loss for Training on Epoch 12 is 0.24015170335769653
# Starting epoch number 13
# yes
# Loss for Training on Epoch 13 is 0.23969684541225433
# Starting epoch number 14
# yes
# Loss for Training on Epoch 14 is 0.23969371616840363
# Starting epoch number 15
# yes
# Loss for Training on Epoch 15 is 0.23883193731307983
# -------  Class: aeroplane        AP:   0.0850  -------
# -------  Class: bicycle          AP:   0.0521  -------
# -------  Class: bird             AP:   0.1308  -------
# -------  Class: boat             AP:   0.0868  -------
# -------  Class: bottle           AP:   0.0458  -------
# -------  Class: bus              AP:   0.0329  -------
# -------  Class: car              AP:   0.1441  -------
# -------  Class: cat              AP:   0.0927  -------
# -------  Class: chair            AP:   0.1444  -------
# -------  Class: cow              AP:   0.0370  -------
# -------  Class: diningtable      AP:   0.0635  -------
# -------  Class: dog              AP:   0.1199  -------
# -------  Class: horse            AP:   0.0544  -------
# -------  Class: motorbike        AP:   0.0416  -------
# -------  Class: person           AP:   0.4833  -------
# -------  Class: pottedplant      AP:   0.0520  -------
# -------  Class: sheep            AP:   0.0508  -------
# -------  Class: sofa             AP:   0.0995  -------
# -------  Class: train            AP:   0.0486  -------
# -------  Class: tvmonitor        AP:   0.0536  -------
# mAP: 0.0959
# Avg loss: 0.23704623252153398
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.09594793124754517
# Starting epoch number 16
# yes
# Loss for Training on Epoch 16 is 0.23851566016674042
# Starting epoch number 17
# yes
# Loss for Training on Epoch 17 is 0.23835788667201996
# Starting epoch number 18
# yes
# Loss for Training on Epoch 18 is 0.23729701340198517
# Starting epoch number 19
# yes
# Loss for Training on Epoch 19 is 0.23651431500911713
# Starting epoch number 20
# yes
# Loss for Training on Epoch 20 is 0.23481670022010803
# -------  Class: aeroplane        AP:   0.1611  -------
# -------  Class: bicycle          AP:   0.0597  -------
# -------  Class: bird             AP:   0.1307  -------
# -------  Class: boat             AP:   0.1245  -------
# -------  Class: bottle           AP:   0.0532  -------
# -------  Class: bus              AP:   0.0462  -------
# -------  Class: car              AP:   0.1795  -------
# -------  Class: cat              AP:   0.0995  -------
# -------  Class: chair            AP:   0.1659  -------
# -------  Class: cow              AP:   0.0399  -------
# -------  Class: diningtable      AP:   0.0810  -------
# -------  Class: dog              AP:   0.1247  -------
# -------  Class: horse            AP:   0.0584  -------
# -------  Class: motorbike        AP:   0.0447  -------
# -------  Class: person           AP:   0.4934  -------
# -------  Class: pottedplant      AP:   0.0584  -------
# -------  Class: sheep            AP:   0.0519  -------
# -------  Class: sofa             AP:   0.1065  -------
# -------  Class: train            AP:   0.0810  -------
# -------  Class: tvmonitor        AP:   0.0552  -------
# mAP: 0.1108
# Avg loss: 0.23651636838912965
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.11076770162877622

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.1219  -------
# -------  Class: bicycle          AP:   0.0569  -------
# -------  Class: bird             AP:   0.1001  -------
# -------  Class: boat             AP:   0.0939  -------
# -------  Class: bottle           AP:   0.0540  -------
# -------  Class: bus              AP:   0.0412  -------
# -------  Class: car              AP:   0.1738  -------
# -------  Class: cat              AP:   0.0999  -------
# -------  Class: chair            AP:   0.1523  -------
# -------  Class: cow              AP:   0.0484  -------
# -------  Class: diningtable      AP:   0.0653  -------
# -------  Class: dog              AP:   0.1312  -------
# -------  Class: horse            AP:   0.0552  -------
# -------  Class: motorbike        AP:   0.0412  -------
# -------  Class: person           AP:   0.4968  -------
# -------  Class: pottedplant      AP:   0.0516  -------
# -------  Class: sheep            AP:   0.0667  -------
# -------  Class: sofa             AP:   0.1079  -------
# -------  Class: train            AP:   0.1007  -------
# -------  Class: tvmonitor        AP:   0.0556  -------
# mAP: 0.1057
# Avg loss: 0.2332504379749298
# Test mAP:  0.10573810208152376

# %% [markdown]
# You should notice somewhat poor performance. You could try running AlexNet with an Adam optimizer instead with learning rate 1e-4 to see if that makes a difference. This experiment is not required for the writeup, but it may show you the importance of a good learning rate and optimizer.

# %% [markdown]
# ## Pretrained AlexNet

# %% [markdown]
# Here we look at the impact of pretrained features. This model's weights were trained on ImageNet, which is a much larger dataset. How do pretrained features perform on VOC? Why do you think there is such a large difference in performance?

# %%
num_epochs = 20
test_frequency = 5

# Load Pretrained AlexNet
classifier = torchvision.models.alexnet(pretrained=True)
classifier.classifier._modules['6'] = nn.Linear(4096, 21)   
classifier = classifier.to(device)
optimizer = torch.optim.SGD(classifier.parameters(), lr=0.01, momentum=0.9)
# Out:
# Downloading: "https://download.pytorch.org/models/alexnet-owt-4df8aa71.pth" to /root/.cache/torch/checkpoints/alexnet-owt-4df8aa71.pth
# HBox(children=(FloatProgress(value=0.0, max=244418560.0), HTML(value='')))

# %%
classifier, train_losses, val_losses, train_mAPs, val_mAPs = train(classifier, num_epochs, train_loader, val_loader, criterion, optimizer, test_frequency)
# Out:
# Starting epoch number 1
# yes
# Loss for Training on Epoch 1 is 0.21756896376609802
# -------  Class: aeroplane        AP:   0.7213  -------
# -------  Class: bicycle          AP:   0.5863  -------
# -------  Class: bird             AP:   0.7984  -------
# -------  Class: boat             AP:   0.6340  -------
# -------  Class: bottle           AP:   0.2443  -------
# -------  Class: bus              AP:   0.5427  -------
# -------  Class: car              AP:   0.7604  -------
# -------  Class: cat              AP:   0.7071  -------
# -------  Class: chair            AP:   0.5699  -------
# -------  Class: cow              AP:   0.3004  -------
# -------  Class: diningtable      AP:   0.4670  -------
# -------  Class: dog              AP:   0.6261  -------
# -------  Class: horse            AP:   0.6505  -------
# -------  Class: motorbike        AP:   0.6475  -------
# -------  Class: person           AP:   0.9015  -------
# -------  Class: pottedplant      AP:   0.3286  -------
# -------  Class: sheep            AP:   0.3152  -------
# -------  Class: sofa             AP:   0.4297  -------
# -------  Class: train            AP:   0.8266  -------
# -------  Class: tvmonitor        AP:   0.5510  -------
# mAP: 0.5804
# Avg loss: 0.13833920851349832
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 1 is 0.5804187971168571
# Starting epoch number 2
# yes
# Loss for Training on Epoch 2 is 0.11869356036186218
# Starting epoch number 3
# yes
# Loss for Training on Epoch 3 is 0.10100679099559784
# Starting epoch number 4
# yes
# Loss for Training on Epoch 4 is 0.08973534405231476
# Starting epoch number 5
# yes
# Loss for Training on Epoch 5 is 0.07775457948446274
# -------  Class: aeroplane        AP:   0.8439  -------
# -------  Class: bicycle          AP:   0.7407  -------
# -------  Class: bird             AP:   0.8599  -------
# -------  Class: boat             AP:   0.7706  -------
# -------  Class: bottle           AP:   0.4015  -------
# -------  Class: bus              AP:   0.6282  -------
# -------  Class: car              AP:   0.8187  -------
# -------  Class: cat              AP:   0.7932  -------
# -------  Class: chair            AP:   0.6096  -------
# -------  Class: cow              AP:   0.4883  -------
# -------  Class: diningtable      AP:   0.5738  -------
# -------  Class: dog              AP:   0.7210  -------
# -------  Class: horse            AP:   0.7535  -------
# -------  Class: motorbike        AP:   0.7940  -------
# -------  Class: person           AP:   0.9071  -------
# -------  Class: pottedplant      AP:   0.4644  -------
# -------  Class: sheep            AP:   0.5962  -------
# -------  Class: sofa             AP:   0.5371  -------
# -------  Class: train            AP:   0.8936  -------
# -------  Class: tvmonitor        AP:   0.6602  -------
# mAP: 0.6928
# Avg loss: 0.11841330125927925
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 5 is 0.6927804158712737
# Starting epoch number 6
# yes
# Loss for Training on Epoch 6 is 0.06885191053152084
# Starting epoch number 7
# yes
# Loss for Training on Epoch 7 is 0.059393756091594696
# Starting epoch number 8
# yes
# Loss for Training on Epoch 8 is 0.05188705399632454
# Starting epoch number 9
# yes
# Loss for Training on Epoch 9 is 0.04535726457834244
# Starting epoch number 10
# yes
# Loss for Training on Epoch 10 is 0.03818286210298538
# -------  Class: aeroplane        AP:   0.8495  -------
# -------  Class: bicycle          AP:   0.7068  -------
# -------  Class: bird             AP:   0.8651  -------
# -------  Class: boat             AP:   0.7528  -------
# -------  Class: bottle           AP:   0.3937  -------
# -------  Class: bus              AP:   0.6211  -------
# -------  Class: car              AP:   0.8135  -------
# -------  Class: cat              AP:   0.7887  -------
# -------  Class: chair            AP:   0.5754  -------
# -------  Class: cow              AP:   0.5127  -------
# -------  Class: diningtable      AP:   0.5892  -------
# -------  Class: dog              AP:   0.7236  -------
# -------  Class: horse            AP:   0.7555  -------
# -------  Class: motorbike        AP:   0.7801  -------
# -------  Class: person           AP:   0.9051  -------
# -------  Class: pottedplant      AP:   0.4558  -------
# -------  Class: sheep            AP:   0.5902  -------
# -------  Class: sofa             AP:   0.5067  -------
# -------  Class: train            AP:   0.8774  -------
# -------  Class: tvmonitor        AP:   0.6337  -------
# mAP: 0.6848
# Avg loss: 0.13628649935126305
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 10 is 0.6848339081351271
# Starting epoch number 11
# yes
# Loss for Training on Epoch 11 is 0.03375811129808426
# Starting epoch number 12
# yes
# Loss for Training on Epoch 12 is 0.030352959409356117
# Starting epoch number 13
# yes
# Loss for Training on Epoch 13 is 0.025650162249803543
# Starting epoch number 14
# yes
# Loss for Training on Epoch 14 is 0.02292090281844139
# Starting epoch number 15
# yes
# Loss for Training on Epoch 15 is 0.020217498764395714
# -------  Class: aeroplane        AP:   0.8592  -------
# -------  Class: bicycle          AP:   0.6994  -------
# -------  Class: bird             AP:   0.8512  -------
# -------  Class: boat             AP:   0.7510  -------
# -------  Class: bottle           AP:   0.3754  -------
# -------  Class: bus              AP:   0.6057  -------
# -------  Class: car              AP:   0.8134  -------
# -------  Class: cat              AP:   0.7934  -------
# -------  Class: chair            AP:   0.5359  -------
# -------  Class: cow              AP:   0.5054  -------
# -------  Class: diningtable      AP:   0.5387  -------
# -------  Class: dog              AP:   0.7171  -------
# -------  Class: horse            AP:   0.7631  -------
# -------  Class: motorbike        AP:   0.7974  -------
# -------  Class: person           AP:   0.9035  -------
# -------  Class: pottedplant      AP:   0.4418  -------
# -------  Class: sheep            AP:   0.5614  -------
# -------  Class: sofa             AP:   0.5009  -------
# -------  Class: train            AP:   0.8760  -------
# -------  Class: tvmonitor        AP:   0.6307  -------
# mAP: 0.6760
# Avg loss: 0.16489251628518103
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 15 is 0.676035090804106
# Starting epoch number 16
# yes
# Loss for Training on Epoch 16 is 0.017417460680007935
# Starting epoch number 17
# yes
# Loss for Training on Epoch 17 is 0.016233259811997414
# Starting epoch number 18
# yes
# Loss for Training on Epoch 18 is 0.013364449143409729
# Starting epoch number 19
# yes
# Loss for Training on Epoch 19 is 0.014394928701221943
# Starting epoch number 20
# yes
# Loss for Training on Epoch 20 is 0.012227309867739677
# -------  Class: aeroplane        AP:   0.8561  -------
# -------  Class: bicycle          AP:   0.7075  -------
# -------  Class: bird             AP:   0.8510  -------
# -------  Class: boat             AP:   0.7238  -------
# -------  Class: bottle           AP:   0.3538  -------
# -------  Class: bus              AP:   0.5779  -------
# -------  Class: car              AP:   0.8144  -------
# -------  Class: cat              AP:   0.7938  -------
# -------  Class: chair            AP:   0.5654  -------
# -------  Class: cow              AP:   0.4827  -------
# -------  Class: diningtable      AP:   0.5732  -------
# -------  Class: dog              AP:   0.7022  -------
# -------  Class: horse            AP:   0.7571  -------
# -------  Class: motorbike        AP:   0.7891  -------
# -------  Class: person           AP:   0.9042  -------
# -------  Class: pottedplant      AP:   0.4355  -------
# -------  Class: sheep            AP:   0.5892  -------
# -------  Class: sofa             AP:   0.4934  -------
# -------  Class: train            AP:   0.8818  -------
# -------  Class: tvmonitor        AP:   0.6301  -------
# mAP: 0.6741
# Avg loss: 0.18774187996983527
# Evaluating classifier
# Mean Precision Score for Testing on Epoch 20 is 0.6740971204674819

# %%
plot_losses(train_losses, val_losses, test_frequency, num_epochs)
plot_mAP(train_mAPs, val_mAPs, test_frequency, num_epochs)

# %%
mAP_test, test_loss, test_aps = test_classifier(test_loader, classifier, criterion)
print("Test mAP: ", mAP_test)
# Out:
# -------  Class: aeroplane        AP:   0.8544  -------
# -------  Class: bicycle          AP:   0.7617  -------
# -------  Class: bird             AP:   0.8244  -------
# -------  Class: boat             AP:   0.7815  -------
# -------  Class: bottle           AP:   0.3077  -------
# -------  Class: bus              AP:   0.6445  -------
# -------  Class: car              AP:   0.8347  -------
# -------  Class: cat              AP:   0.7769  -------
# -------  Class: chair            AP:   0.5576  -------
# -------  Class: cow              AP:   0.5100  -------
# -------  Class: diningtable      AP:   0.5958  -------
# -------  Class: dog              AP:   0.7109  -------
# -------  Class: horse            AP:   0.8534  -------
# -------  Class: motorbike        AP:   0.7585  -------
# -------  Class: person           AP:   0.9168  -------
# -------  Class: pottedplant      AP:   0.4432  -------
# -------  Class: sheep            AP:   0.6564  -------
# -------  Class: sofa             AP:   0.5262  -------
# -------  Class: train            AP:   0.8668  -------
# -------  Class: tvmonitor        AP:   0.6279  -------
# mAP: 0.6905
# Avg loss: 0.18216295033693314
# Test mAP:  0.6904668953300196
